# %%
import pandas as pd

df = pd.read_csv("../data/property_assessments.csv")
df.describe(include='all')
# Out:
# /var/folders/mf/_0_42kbd2cd4_260mjyyd1w80000gn/T/ipykernel_68952/1109949117.py:3: DtypeWarning: Columns (15,22,24,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/property_assessments.csv")
#            Unnamed: 0       PROP_ID            LOC_ID      BLDG_VAL  \
# count    98691.000000  9.869100e+04             98690  9.869100e+04
# unique            NaN           NaN             98690           NaN
# top               NaN           NaN  F_783144_2964233           NaN
# freq              NaN           NaN                 1           NaN
# mean     77548.182377  1.336226e+09               NaN  1.054888e+06
# std      46999.636808  6.618119e+08               NaN  1.019501e+07
# min          1.000000  1.000010e+08               NaN  0.000000e+00
# 25%      43807.500000  7.027715e+08               NaN  1.950000e+05
# 50%      70348.000000  1.600462e+09               NaN  3.509000e+05
# 75%     103075.500000  1.900862e+09               NaN  5.480000e+05
# max     175364.000000  2.205670e+09               NaN  8.675339e+08
#
#             LAND_VAL     OTHER_VAL     TOTAL_VAL       FY      LOT_SIZE  \
# count   9.869100e+04  9.869100e+04  9.869100e+04  98691.0  98691.000000
# unique           NaN           NaN           NaN      NaN           NaN
# top              NaN           NaN           NaN      NaN           NaN
# freq             NaN           NaN           NaN      NaN           NaN
# mean    5.493207e+05  5.411864e+03  1.600494e+06   2020.0      0.251263
# std     4.600936e+06  1.192220e+05  1.326258e+07      0.0      8.023299
# min     0.000000e+00  0.000000e+00  0.000000e+00   2020.0      0.000000
# 25%     1.201000e+05  0.000000e+00  3.447000e+05   2020.0      0.000000
# 50%     1.837000e+05  0.000000e+00  5.443000e+05   2020.0      0.000000
# 75%     2.563000e+05  0.000000e+00  8.074000e+05   2020.0      0.020000
# max     4.074475e+08  2.016230e+07  9.404720e+08   2020.0   2330.430000
#
#              LS_DATE  ...  AssessedYear       acreage StandardizedUseCodes  \
# count   9.869000e+04  ...       98654.0  98654.000000                85537
# unique           NaN  ...           NaN           NaN                   77
# top              NaN  ...           NaN           NaN                  101
# freq             NaN  ...           NaN           NaN                30325
# mean    2.005322e+07  ...        2020.0      0.263589                  NaN
# std     1.074409e+05  ...           0.0      3.050093                  NaN
# min     1.986032e+07  ...        2020.0      0.000124                  NaN
# 25%     1.997062e+07  ...        2020.0      0.059262                  NaN
# 50%     2.007081e+07  ...        2020.0      0.098252                  NaN
# 75%     2.015061e+07  ...        2020.0      0.141175                  NaN
# max     2.020012e+07  ...        2020.0    479.484043                  NaN
#
#        StandardizedUseDesc                             NonResidentialUses  \
# count                98654                                          22976
# unique                  75                                             16
# top          Single-family  Tax-exempt, public, charitable, institutional
# freq                 30463                                          16127
# mean                   NaN                                            NaN
# std                    NaN                                            NaN
# min                    NaN                                            NaN
# 25%                    NaN                                            NaN
# 50%                    NaN                                            NaN
# 75%                    NaN                                            NaN
# max                    NaN                                            NaN
#
#                           UseDesc residentialunits    unitsource  \
# count                       98654     98654.000000         98654
# unique                        567              NaN             2
# top     Single Family Residential              NaN  MHP estimate
# freq                        30458              NaN         78832
# mean                          NaN         3.138535           NaN
# std                           NaN        13.348218           NaN
# min                           NaN         0.000000           NaN
# 25%                           NaN         1.000000           NaN
# 50%                           NaN         2.000000           NaN
# 75%                           NaN         3.000000           NaN
# max                           NaN      1478.000000           NaN
#
#                  DUA    Developable
# count   98654.000000           5555
# unique           NaN              3
# top              NaN  Undevelopable
# freq             NaN           4443
# mean       34.590192            NaN
# std        56.053643            NaN
# min         0.000000            NaN
# 25%         6.043586            NaN
# 50%        16.745699            NaN
# 75%        42.127583            NaN
# max      4058.955234            NaN
#
# [11 rows x 50 columns]

# %%
df.head(10)
# Out:
#    Unnamed: 0    PROP_ID            LOC_ID  BLDG_VAL  LAND_VAL  OTHER_VAL  \
# 0           1  100213000  F_783144_2964233         0         0          0
# 1           5  100218000  F_783205_2964264    437000    291800          0
# 2           6  100219000  F_783236_2964275    472900    267300          0
# 3           7  100220000  F_783269_2964282    408300    244900          0
# 4           8  100221000  F_783294_2964292    198800    125100          0
# 5           9  100222000  F_783316_2964279    224000    136600          0
# 6          10  100223000  F_783336_2964280    230700    133600          0
# 7          11  100225000  F_783374_2964284    199600    129200          0
# 8          12  100226000  F_783396_2964287    351200    182600          0
# 9          13  100227000  F_783415_2964290    330300    137000          0
#
#    TOTAL_VAL    FY  LOT_SIZE     LS_DATE  ...  AssessedYear   acreage  \
# 0          0  2020       0.0  19920928.0  ...        2020.0  0.228752
# 1     728800  2020       0.0  19990202.0  ...        2020.0  0.077937
# 2     740200  2020       0.0  20161109.0  ...        2020.0  0.064641
# 3     653200  2020       0.0  19870101.0  ...        2020.0  0.054759
# 4     323900  2020       0.0  20171006.0  ...        2020.0  0.026261
# 5     360600  2020       0.0  19980102.0  ...        2020.0  0.033778
# 6     364300  2020       0.0  19970613.0  ...        2020.0  0.030561
# 7     328800  2020       0.0  20001030.0  ...        2020.0  0.029708
# 8     533800  2020       0.0  20190731.0  ...        2020.0  0.026614
# 9     467300  2020       0.0  20150901.0  ...        2020.0  0.020928
#
#   StandardizedUseCodes StandardizedUseDesc  \
# 0                  102         Condominium
# 1                  105        Three-family
# 2                  105        Three-family
# 3                  105        Three-family
# 4                  101       Single-family
# 5                  101       Single-family
# 6                  101       Single-family
# 7                  101       Single-family
# 8                  105        Three-family
# 9                  104          Two-family
#
#                               NonResidentialUses  \
# 0  Tax-exempt, public, charitable, institutional
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
#
#                                       UseDesc residentialunits    unitsource  \
# 0  Residential Condominium, Other, Open Space              4.0  MHP estimate
# 1                    Three-Family Residential              4.0  MHP estimate
# 2                    Three-Family Residential              4.0  MHP estimate
# 3                    Three-Family Residential              4.0  MHP estimate
# 4                   Single Family Residential              3.0  MHP estimate
# 5                   Single Family Residential              1.0  MHP estimate
# 6                   Single Family Residential              2.0  MHP estimate
# 7                   Single Family Residential              1.0  MHP estimate
# 8                    Three-Family Residential              4.0  MHP estimate
# 9                      Two-Family Residential              2.0  MHP estimate
#
#           DUA Developable
# 0   17.486216         NaN
# 1   51.323242         NaN
# 2   61.879834         NaN
# 3   73.046991         NaN
# 4  114.236512         NaN
# 5   29.605373         NaN
# 6   65.443812         NaN
# 7   33.660575         NaN
# 8  150.298742         NaN
# 9   95.567042         NaN
#
# [10 rows x 50 columns]

# %%
# Check for duplicate data points
duplicates = df.duplicated()
duplicates = duplicates[duplicates == True]
len(duplicates)
# Out:
# 0
