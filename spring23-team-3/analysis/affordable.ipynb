# %%
import pandas as pd

# no duplicate rows
df = pd.read_csv("../data/affordable_rental_units.csv")
df.head(5)
# Out:
#   Neighborhood  \
# 0      Allston
# 1      Allston
# 2      Allston
# 3      Allston
# 4      Allston
#
#   Building Address (click below for property website, where available)  \
# 0                                    8 Griggs Street
# 1                             31 North Beacon Street
# 2                                  40 Malvern Street
# 3                               450 Cambridge Street
# 4                          1505\nCommonwealth Avenue
#
#           For Current Vacancies and More Information  Number of Units Tracked  \
# 0             The Mount Vernon Company: 617.267.0006                      2.0
# 1                    Carol Fiore: cfiore@78clean.com                      3.0
# 2                    40Malvern@maloneyproperties.com                      6.0
# 3  Maloney Properties: 617.209.5406 450Cambridge@...                      5.0
# 4                           LBC Boston: 617.599.7261                     10.0
#
#       Bedroom Sizes AMI Categories
# ...

# %%
violations_df = pd.read_csv("../data/cities_df.csv")
violations_df.head(5)
# Out:
#    Unnamed: 0      Location  Hot Water  Potable Water  \
# 0           0        boston       30.0            1.0
# 1           1    dorchester       29.0            3.0
# 2           2       roxbury       15.0            0.0
# 3           3  jamaicaplain       10.0            1.0
# 4          18   southboston        2.0            0.0
#
#    Heating Facilities Required  Temperature Requirements  Asbestos Material  \
# 0                         45.0                      40.0                0.0
# 1                         41.0                      32.0                0.0
# 2                         17.0                      12.0                0.0
# 3                         14.0                       7.0                0.0
# 4                         21.0                       9.0                0.0
#
#    Use of Lead Paint Prohibited  Safe Condition  \
# 0                           0.0             2.0
# 1                           1.0             7.0
# ...
